# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1' : [1,2,3,4], 'col2' : ["Keshav","Srinidhi","Chandan","Aswin"], 'col3' : [111,112,113,114]})

# %%
df
# Out:
#    col1      col2  col3
# 0     1    Keshav   111
# 1     2  Srinidhi   112
# 2     3   Chandan   113
# 3     4     Aswin   114

# %%
df.head()
# Out:
#    col1      col2  col3
# 0     1    Keshav   111
# 1     2  Srinidhi   112
# 2     3   Chandan   113
# 3     4     Aswin   114

# %%
df.tail()
# Out:
#    col1      col2  col3
# 0     1    Keshav   111
# 1     2  Srinidhi   112
# 2     3   Chandan   113
# 3     4     Aswin   114

# %%
df['col2'].count()
# Out:
# 4

# %%
df['col2'].unique()
# Out:
# array(['Keshav', 'Srinidhi', 'Chandan', 'Aswin'], dtype=object)

# %%
df['col2'].nunique()
# Out:
# 4

# %%
df['col2'].value_counts()
# Out:
# col2
# Keshav      1
# Srinidhi    1
# Chandan     1
# Aswin       1
# Name: count, dtype: int64

# %%
import numpy as np
df2 = pd.DataFrame({'col1' : [10,np.nan,30,40], 'col2' : ['aaa','bbb',np.nan,'ddd'], 'col3' : [111,222,333,np.nan]})

# %%
df2
# Out:
#    col1 col2   col3
# 0  10.0  aaa  111.0
# 1   NaN  bbb  222.0
# 2  30.0  NaN  333.0
# 3  40.0  ddd    NaN

# %%
df2.dropna()
# Out:
#    col1 col2   col3
# 0  10.0  aaa  111.0

# %%
del df['col2']

# %%
df
# Out:
#    col1  col3
# 0     1   111
# 1     2   112
# 2     3   113
# 3     4   114

# %%
df2.sort_values(by = 'col1')
# Out:
#    col1 col2   col3
# 0  10.0  aaa  111.0
# 2  30.0  NaN  333.0
# 3  40.0  ddd    NaN
# 1   NaN  bbb  222.0

# %%
df2.fillna('FILL')
# Out:
#    col1  col2   col3
# 0  10.0   aaa  111.0
# 1  FILL   bbb  222.0
# 2  30.0  FILL  333.0
# 3  40.0   ddd   FILL
